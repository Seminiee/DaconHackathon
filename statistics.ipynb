# %%
#데이터 자료구조 패키지 임포트
import pandas as pd
import numpy as np

# %%
#request를 이용해서 웹 csv 파일을 가져오기
#1. os 패키지를 이용하여 다운로드 받을 디렉토리 지정
#추후 알아볼 예정
import os
import requests as req

url = "https://raw.githubusercontent.com/Datamanim/datarepo/main/adp/29/p1.csv"
base_Path = '/home/semin/vscode_workspace_wsl/semin_adp'
data_Path = '/raw_data'
os.chdir(base_Path + data_Path)
os.getcwd() #현재 작업하고 있는 디렉토리 얻기

# %%
base_Path = '/home/semin/vscode_workspace_wsl/semin_adp'
data_Path = '/raw_data/'
data_Filename = 'p1.csv'
data_p1 = pd.read_csv(base_Path+data_Path+data_Filename,encoding='cp949')

data_p1.info()
#data_p1.head()

# %%
data_p1.head()

# %% [markdown]
# #'1-1 계약자고유번호를 기준으로 거주연도 별 여러개의 데이터가 쌓여 있다. 각 계약자고유번호에 대해 가장 최신의 거주연도 행만 남겨라.

# %%
data_p1.columns

# %%
'''
dp1_groupby = data_p1.grou
pby(by = data_p1["계약자고유번호"])
dp1_groupby
'''

# %%
data_p1[['계약자고유번호']]

# %%
#M3 Pro Macbook Pro와 비교를 위해 테스트 진행

#'''
import tensorflow as tf

cifar = tf.keras.datasets.cifar100
(x_train, y_train), (x_test, y_test) = cifar.load_data()
model = tf.keras.applications.ResNet50(
    include_top=True,
    weights=None,
    input_shape=(32, 32, 3),
    classes=100,)

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
model.compile(optimizer="adam", loss=loss_fn, metrics=["accuracy"])
model.fit(x_train, y_train, epochs=25, batch_size=64)

#'''
# Out:
# 2024-02-26 19:15:36.181349: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-02-26 19:15:36.201791: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-26 19:15:36.624141: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-02-26 19:15:37.292103: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# ...
