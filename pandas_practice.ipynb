# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## `pandas.series`
# - 굳이 생성해서 쓸 일은 거의 없음
# - pandas의 기본 객체 중 하나
# - numpy의 ndarray를 기반으로 인덱싱 기능을 추가하여 1차원 배열을 나타냄
# - index를 지정하지 않을 시, ndarray와 같이 0-based 인덱스 생성, 지정할 경우 명시적으로 지정된 index를 사용
# - 같은 타입의 0개 이상의 데이터를 가질 수 있음

# %% [markdown]
# - data로만 생성하기
#     - index는 기본적으로 0부터 자동적으로 생성

# %%
s1 = pd.Series([1, 2, 3])
s1
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
s2 = pd.Series(['a', 'b', 'c'])
s2
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
s3 = pd.Series(np.arange(200))
s3
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 195    195
# 196    196
# 197    197
# 198    198
# 199    199
# Length: 200, dtype: int64

# %% [markdown]
# - data, index 함께 명시하기

# %%
s4 = pd.Series([1,2,3], [100, 200, 300])
s4
# Out:
# 100    1
# 200    2
# 300    3
# dtype: int64

# %%
s5 = pd.Series([1, 2, 3], ['a', 'm', 'k'])
s5
# Out:
# a    1
# m    2
# k    3
# dtype: int64

# %% [markdown]
# - data, index, dtype 함께 명시하기
#     - dtype은 명시하지 않으면 pandas가 알아서 os와 입력한 데이터 타입에 맞게 유추한다

# %%
s6 = pd.Series(np.arange(5), np.arange(100,105), dtype=np.int32)
s6
# Out:
# 100    0
# 101    1
# 102    2
# 103    3
# 104    4
# dtype: int32

# %% [markdown]
# ### 인덱스 활용하기

# %%
s6.index
# Out:
# Index([100, 101, 102, 103, 104], dtype='int64')

# %%
s6.values
# Out:
# array([0, 1, 2, 3, 4], dtype=int32)

# %%
s6[0] # Error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/envs/dl/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 s6[0] # Error
#
# ...

# %% [markdown]
# 1. 인덱스를 통한 데이터 접근

# %%
s6[104]
# Out:
# 4

# %% [markdown]
# 2. 인덱스를 통한 데이터 업데이트
# - 업데이트의 경우, 인덱스가 존재하지 않으면 주어진 인덱스로 하는 데이터 생성

# %%
s6[104] = 70
s6
# Out:
# 100     0
# 101     1
# 102     2
# 103     3
# 104    70
# dtype: int32

# %%
s6[200] = 80
s6
# Out:
# 100     0
# 101     1
# 102     2
# 103     3
# 104    70
# 200    80
# dtype: int32

# %% [markdown]
# 3. 인덱스 재사용하기

# %%
s7 = pd.Series(np.arange(6), s6.index)
s7
# Out:
# 100    0
# 101    1
# 102    2
# 103    3
# 104    4
# 200    5
# dtype: int64

# %% [markdown]
# # Series 데이터 심플 분석(개수, 빈도 등 계산하기)

# %% [markdown]
# ## Series `size`, `shape`, `unique`, `count`, `value_counts` 함수
# - `size`: 개수 반환
# - `shape`: 튜플 형태로 shape 반환
# - `unique`: 유일한 값만 ndarray로 반환
# - `count`: NaN을 제외한 개수를 반환
# - `mean`: NaN을 제외한 평균
# - `value_counts`: NaN을 제외하고 각 값들의 빈도를 반환

# %%
s = pd.Series([1,1,2,1,2,2,2,1,1,3, 3, 4, 5, 5, 7, np.NaN])
s
# Out:
# 0     1.0
# 1     1.0
# 2     2.0
# 3     1.0
# 4     2.0
# 5     2.0
# 6     2.0
# 7     1.0
# 8     1.0
# 9     3.0
# 10    3.0
# 11    4.0
# 12    5.0
# 13    5.0
# 14    7.0
# 15    NaN
# dtype: float64

# %%
len(s)
# Out:
# 16

# %%
s.size
# Out:
# 16

# %%
s.shape
# Out:
# (16,)

# %%
s.unique()
# Out:
# array([ 1.,  2.,  3.,  4.,  5.,  7., nan])

# %%
s.count()
# Out:
# 15

# %%
a = np.array([2, 2, 2, 2, np.NaN]) # ndarray -> NaN이 있으면 연산 불가
a.mean()
# Out:
# nan

# %%
s.mean()
# Out:
# 2.6666666666666665

# %%
s.value_counts()
# Out:
# 1.0    5
# 2.0    4
# 3.0    2
# 5.0    2
# 4.0    1
# 7.0    1
# Name: count, dtype: int64

# %% [markdown]
# ### index를 활용하여 멀티플한 값에 접근
# - index를 리스트로 주면 된다

# %%
s[[5, 7, 8, 10]].value_counts()
# Out:
# 1.0    2
# 2.0    1
# 3.0    1
# Name: count, dtype: int64

# %% [markdown]
# ## `head`, `tail` 함수
# - `head`: 상위 n개 출력 (기본 5개)
# - `tail`: 하위 n개 출력 (기본 5개)

# %%
s.head()
# Out:
# 0    1.0
# 1    1.0
# 2    2.0
# 3    1.0
# 4    2.0
# dtype: float64

# %%
s.head(10)
# Out:
# 0    1.0
# 1    1.0
# 2    2.0
# 3    1.0
# 4    2.0
# 5    2.0
# 6    2.0
# 7    1.0
# 8    1.0
# 9    3.0
# dtype: float64

# %%
s.tail()
# Out:
# 11    4.0
# 12    5.0
# 13    5.0
# 14    7.0
# 15    NaN
# dtype: float64

# %% [markdown]
# # Series 데이터 연산하기

# %% [markdown]
# ## index를 기준으로 연산

# %% [markdown]
# ### 산술연산
# - Series의 경우에도 스칼라와의 연산은 각 원소별로 스칼라와의 연산이 적용
# - Series와의 연산은 각 인덱스에 맞는 값끼리 연산이 적용
#     - 이 때, 인덱스의 pair가 맞지 않으면, 결과는 NaN

# %%
s1 = pd.Series([1,2,3,4], ['a','b','c','d'])
s2 = pd.Series([6,3,2,1], ['d', 'c', 'b','a'])

s1
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
s2
# Out:
# d    6
# c    3
# b    2
# a    1
# dtype: int64

# %%
s1 + s2 # 같은 인덱스 끼리 연산
# Out:
# a     2
# b     4
# c     6
# d    10
# dtype: int64

# %%
s1 ** 2
# Out:
# a     1
# b     4
# c     9
# d    16
# dtype: int64

# %%
s1 ** s2
# Out:
# a       1
# b       4
# c      27
# d    4096
# dtype: int64

# %% [markdown]
# ### index pair가 맞지 않는 경우
# - 해당 index에 대해선 NaN 값 생성

# %%
s1['k'] = 7
s2['e'] = 9

s1
# Out:
# a    1
# b    2
# c    3
# d    4
# k    7
# dtype: int64

# %%
s2
# Out:
# d    6
# c    3
# b    2
# a    1
# e    9
# dtype: int64

# %%
s1 + s2
# Out:
# a     2.0
# b     4.0
# c     6.0
# d    10.0
# e     NaN
# k     NaN
# dtype: float64

# %% [markdown]
# ## Series 데이터 Boolean Selection으로 데이터 선택하기

# %% [markdown]
# ### Boolean Selection
# - boolean Series가 []와 함게 사용되면 True 값에 해당하는 값만 새로 반환되는 Series 객체에 포함됨
# - 다중 조건의 경우, &(and), |(or)를 사용하여 연결 가능

# %%
s = pd.Series(np.arange(10), np.arange(10) + 1)
s
# Out:
# 1     0
# 2     1
# 3     2
# 4     3
# 5     4
# 6     5
# 7     6
# 8     7
# 9     8
# 10    9
# dtype: int64

# %%
s > 5
# Out:
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8      True
# 9      True
# 10     True
# dtype: bool

# %%
s[s > 5]
# Out:
# 7     6
# 8     7
# 9     8
# 10    9
# dtype: int64

# %%
s[s % 2 == 0]
# Out:
# 1    0
# 3    2
# 5    4
# 7    6
# 9    8
# dtype: int64

# %%
s
# Out:
# 1     0
# 2     1
# 3     2
# 4     3
# 5     4
# 6     5
# 7     6
# 8     7
# 9     8
# 10    9
# dtype: int64

# %%
s.index > 5
# Out:
# array([False, False, False, False, False,  True,  True,  True,  True,
#         True])

# %%
s[s.index > 5]
# Out:
# 6     5
# 7     6
# 8     7
# 9     8
# 10    9
# dtype: int64

# %%
s[(s > 5) & (s < 8)] # Multiple 조건은 각 조건(condition)을 괄호로 묶어야 함
# Out:
# 7    6
# 8    7
# dtype: int64

# %%
# 문제

(s >= 7).sum() # 7이상의 값의 개수
(s[s>=7]).sum() # 7이상의 값의 합
# Out:
# 24

# %% [markdown]
# # Series 데이터 변경 & 슬라이싱 하기

# %% [markdown]
# ### Series 값 변경
# - 추가 및 업데이트: 인덱스를 이용
# - 삭제: drop 함수 이용
#     - 새로운 Series 반환(원본 변경 없음)

# %%
s = pd.Series(np.arange(100, 105), ['a', 'b', 'c', 'd', 'e'])
s
# Out:
# a    100
# b    101
# c    102
# d    103
# e    104
# dtype: int64

# %%
s['a'] = 200
s
# Out:
# a    200
# b    101
# c    102
# d    103
# e    104
# dtype: int64

# %%
s['k'] = 300
s
# Out:
# a    200
# b    101
# c    102
# d    103
# e    104
# k    300
# dtype: int64

# %%
s.drop('k') # 복사본 반환
# Out:
# a    200
# b    101
# c    102
# d    103
# e    104
# dtype: int64

# %%
s
# Out:
# a    200
# b    101
# c    102
# d    103
# e    104
# k    300
# dtype: int64

# %%
s.drop('k', inplace = True) # 반환값이 없음 -> 복사본이 아니라 원본에 대해서 연산 적용

# %%
s
# Out:
# a    200
# b    101
# c    102
# d    103
# e    104
# dtype: int64

# %%
s[['a', 'b']] = [300, 900]
s
# Out:
# a    300
# b    900
# c    102
# d    103
# e    104
# dtype: int64

# %% [markdown]
# ### Slicing
# - 리스트, ndarray와 동일하게 적용

# %%
s1 = pd.Series(np.arange(100, 105))
s1
# Out:
# 0    100
# 1    101
# 2    102
# 3    103
# 4    104
# dtype: int64

# %%
s1[1:3] # 정수 인덱스 접근 시 ndarray와 동일함
# Out:
# 1    101
# 2    102
# dtype: int64

# %%
s2 = pd.Series(np.arange(100, 105), ['a','b','c','d','e'])
s2
# Out:
# a    100
# b    101
# c    102
# d    103
# e    104
# dtype: int64

# %%
s2[1:3] # 문자열 인덱스 시 인덱스 순서대로 접근, 마지막 인덱스는 포함 X
# Out:
# b    101
# c    102
# dtype: int64

# %%
s3 = pd.Series(np.arange(100, 105), ['a','c','b','d','e'])
s3
# Out:
# a    100
# c    101
# b    102
# d    103
# e    104
# dtype: int64

# %%
s3['c':'d'] # 문자열 인덱스로 슬라이싱 시 마지막 인덱스를 포함
# Out:
# c    101
# b    102
# d    103
# dtype: int64

# %% [markdown]
# # `Pandas.DataFrame`
#
# ## DataFrame
# - Series가 1차원이라면, DataFrame은 2차원으로 확대된 버전
# - Excel spreadsheet이라고 생각하면 이해하기 쉬움
# - 2차원이기 때문에 인덱스가 row, column으로 구성됨
#     - row는 각 개별 데이터를, column은 개별 속성을 의미
# - Data Analysis, Machine Learning에서 data 변형을 위해 가장 많이 사용

# %%
import os
import pandas as pd
data_path = '../../kaggle_data/titanic'
file_name = 'train.csv'

train_data = pd.read_csv(os.path.join(data_path, file_name))

# %% [markdown]
# ### `head`, `tail` 함수
# - 데이터 전체가 아닌, 일부(처음부터, 혹은 마지막 부터)를 간단히 보기 위한 함수
# - head: 상위 n개 데이터 (기본 5개)
# - tail: 하위 n개 데이터 (기본 5개)

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ### dataframe 데이터 파악하기
# - shape 속성(row, column)
# - `describe` 함수 - 숫자형 데이터의 통계치 계산
# - `info` 함수 - 데이터 타입, 각 아이템의 개수 등 출력

# %%
train_data.shape
# Out:
# (891, 12)

# %%
train_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ## DataFrame 구조 이해하기

# %% [markdown]
# ### 인덱스 (index)
# - index 속성 `dataframe.index`
# - 각 아이템을 특정할 수 있는 고유의 값을 저장
#         - 절대로 중복이 있을 수 없다
# - 복잡한 데이터의 경우, 멀티 인덱스로 표현 가능

# %%
train_data.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
train_data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ## cf\) DataFrame 데이터 생성하기

# %% [markdown]
# ### DataFrame 생성하기
# - 일반적으로 분석을 위한 데이터는 다른 데이터 소스(database, 외부 파일)를 통해 dataframe을 생성
# - 실습에서는 dummy 데이터를 생성하는 방법을 다룸

# %% [markdown]
# #### dictionary로 부터 생성하기
# - dict의 key -> column

# %%
data = {'a': 100, 'b': 200, 'c' : 300}
df1 = pd.DataFrame(data, index=['x', 'y', 'z'])
df1
# Out:
#      a    b    c
# x  100  200  300
# y  100  200  300
# z  100  200  300

# %%
data = {'a': [1,2,3], 'b': [4,5,6], 'c' : [10,11,12]}
df2 = pd.DataFrame(data, index = [0, 1, 2])
df2
# Out:
#    a  b   c
# 0  1  4  10
# 1  2  5  11
# 2  3  6  12

# %% [markdown]
# #### Series로 부터 생성하기
# - 각 Series의 인덱스 -> column

# %%
a = pd.Series([100, 200, 300], ['a', 'b', 'd'])
b = pd.Series([101, 201, 301], ['a', 'b', 'k'])
c = pd.Series([110, 220, 310], ['a', 'b', 'c'])

pd.DataFrame([a,b,c], index = [100, 101, 102])
# Out:
#          a      b      d      k      c
# 100  100.0  200.0  300.0    NaN    NaN
# 101  101.0  201.0    NaN  301.0    NaN
# 102  110.0  220.0    NaN    NaN  310.0

# %% [markdown]
# ## 샘플 CSV 데이터로 DataFrame 데이터 생성하기

# %% [markdown]
# ### `pandas.read_csv()`함수와 파라미터
# - sep: 각 데이터 값을 구별하기 위한 구분자(separator) 설정
#     - sep의 기본값은 ','
# - header: header를 무시할 경우 None
#     - 자동으로 유추
# - index_col: index로 사용할 column 설정
#     - 명시하지 않으면 0 based 인덱스 생성
# - usecols: 실제로 dataframe에 로딩할 columns만 설정

# %%
import os
import pandas as pd
data_path = '../../kaggle_data/titanic'
file_name = 'train.csv'

train_data = pd.read_csv(os.path.join(data_path, file_name))

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_data = pd.read_csv(os.path.join(data_path, file_name), index_col = 'PassengerId')
train_data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# ## DataFrame 원하는 column만 선택하기

# %% [markdown]
# ### column 선택하기
# - 기본적으로 []는 column을 추출
# - 컬럼 인덱스일 경우, 인덱스의 리스트 사용 가능
#     - 리스트를 전달할 경우 결과는 DataFrame
#     - 하나의 컬럼명을 전달할 경우 결과는 Series

# %% [markdown]
# #### 하나의 컬럼 선택하기

# %%
train_data[0] # Error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/envs/dl/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[85], line 2
#       1 #### 하나의 컬럼 선택하기
# ----> 2 train_data[0]
#
# ...

# %%
train_data['Survived'] # 결과는 Series
# Out:
# PassengerId
# 1      0
# 2      1
# 3      1
# 4      1
# 5      0
#       ..
# 887    0
# 888    1
# 889    0
# 890    1
# 891    0
# Name: Survived, Length: 891, dtype: int64

# %%
train_data[['Survived']] # 결과는 DataFrame
# Out:
#              Survived
# PassengerId
# 1                   0
# 2                   1
# 3                   1
# 4                   1
# 5                   0
# ...               ...
# 887                 0
# 888                 1
# 889                 0
# 890                 1
# 891                 0
#
# [891 rows x 1 columns]

# %% [markdown]
# #### 복수의 컬럼 선택하기

# %%
train_data[['Survived', 'Age', 'Name']] # 결과는 DataFrame
# Out:
#              Survived   Age                                               Name
# PassengerId
# 1                   0  22.0                            Braund, Mr. Owen Harris
# 2                   1  38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                   1  26.0                             Heikkinen, Miss. Laina
# 4                   1  35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                   0  35.0                           Allen, Mr. William Henry
# ...               ...   ...                                                ...
# 887                 0  27.0                              Montvila, Rev. Juozas
# 888                 1  19.0                       Graham, Miss. Margaret Edith
# 889                 0   NaN           Johnston, Miss. Catherine Helen "Carrie"
# 890                 1  26.0                              Behr, Mr. Karl Howell
# 891                 0  32.0                                Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# ## DataFrame 원하는 row(데이터)만 선택하기

# %% [markdown]
# ### dataframe slicing
# - dataframe의 경우 기본적으로 [] 연산자가 column 선택에 사용
# - 하지만 slicing은 row 레벨로 지원

# %%
train_data = pd.read_csv(os.path.join(data_path, file_name))
train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# train_data[0] # Error
train_data[:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
train_data[7:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch  Ticket     Fare Cabin Embarked
# 7      1  349909  21.0750   NaN        S
# 8      2  347742  11.1333   NaN        S
# 9      0  237736  30.0708   NaN        C

# %% [markdown]
# ### row 선택하기
# - Series의 경우 []로 row 선택이 가능하나, DataFrame의 경우는 기본적으로 column을 선택하도록 설계
# - `.loc`, `.iloc`으로 row 선택 가능
#     - `.loc`: 해당 데이터프레임의 인덱스 자체를 사용
#     - `.iloc`: 0 based index로 사용
#     - 두 함수는 `,`를 사용하여 column 선택도 가능
#         - `loc`: 원 column_name으로 접근
#         - `iloc`: column 또한 0 based index이기 때문에 정수 index로 접근

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train_data.index = np.arange(100, 991)

# %%
train_data.head()
# Out:
#      PassengerId  Survived  Pclass  \
# 100            1         0       3
# 101            2         1       1
# 102            3         1       3
# 103            4         1       1
# 104            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 100                            Braund, Mr. Owen Harris    male  22.0      1
# 101  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 102                             Heikkinen, Miss. Laina  female  26.0      0
# 103       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 104                           Allen, Mr. William Henry    male  35.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 100      0         A/5 21171   7.2500   NaN        S
# 101      0          PC 17599  71.2833   C85        C
# 102      0  STON/O2. 3101282   7.9250   NaN        S
# 103      0            113803  53.1000  C123        S
# ...

# %%
train_data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 986          887         0       2                     Montvila, Rev. Juozas
# 987          888         1       1              Graham, Miss. Margaret Edith
# 988          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 989          890         1       1                     Behr, Mr. Karl Howell
# 990          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 986    male  27.0      0      0      211536  13.00   NaN        S
# 987  female  19.0      0      0      112053  30.00   B42        S
# 988  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 989    male  26.0      0      0      111369  30.00  C148        C
# 990    male  32.0      0      0      370376   7.75   NaN        Q

# %%
train_data.loc[986] # 결과는 Series
# Out:
# PassengerId                      887
# Survived                           0
# Pclass                             2
# Name           Montvila, Rev. Juozas
# Sex                             male
# Age                             27.0
# SibSp                              0
# Parch                              0
# Ticket                        211536
# Fare                            13.0
# Cabin                            NaN
# Embarked                           S
# Name: 986, dtype: object

# %%
train_data.loc[[986, 100, 110, 990]]
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 986          887         0       2            Montvila, Rev. Juozas    male
# 100            1         0       3          Braund, Mr. Owen Harris    male
# 110           11         1       3  Sandstrom, Miss. Marguerite Rut  female
# 990          891         0       3              Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch     Ticket   Fare Cabin Embarked
# 986  27.0      0      0     211536  13.00   NaN        S
# 100  22.0      1      0  A/5 21171   7.25   NaN        S
# 110   4.0      1      1    PP 9549  16.70    G6        S
# 990  32.0      0      0     370376   7.75   NaN        Q

# %%
train_data.head()
# Out:
#      PassengerId  Survived  Pclass  \
# 100            1         0       3
# 101            2         1       1
# 102            3         1       3
# 103            4         1       1
# 104            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 100                            Braund, Mr. Owen Harris    male  22.0      1
# 101  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 102                             Heikkinen, Miss. Laina  female  26.0      0
# 103       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 104                           Allen, Mr. William Henry    male  35.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 100      0         A/5 21171   7.2500   NaN        S
# 101      0          PC 17599  71.2833   C85        C
# 102      0  STON/O2. 3101282   7.9250   NaN        S
# 103      0            113803  53.1000  C123        S
# ...

# %%
train_data.iloc[0] # 결과는 Series
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 100, dtype: object

# %%
train_data.iloc[[0, 100, 200 ,2]]
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 100            1         0       3         Braund, Mr. Owen Harris    male
# 200          101         0       3         Petranec, Miss. Matilda  female
# 300          201         0       3  Vande Walle, Mr. Nestor Cyriel    male
# 102            3         1       3          Heikkinen, Miss. Laina  female
#
#       Age  SibSp  Parch            Ticket    Fare Cabin Embarked
# 100  22.0      1      0         A/5 21171  7.2500   NaN        S
# 200  28.0      0      0            349245  7.8958   NaN        S
# 300  28.0      0      0            345770  9.5000   NaN        S
# 102  26.0      0      0  STON/O2. 3101282  7.9250   NaN        S

# %%
train_data.loc[[0, 100, 200 ,2]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 train_data.loc[[0, 100, 200 ,2]]
#
# File ~/miniforge3/envs/dl/lib/python3.9/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/miniforge3/envs/dl/lib/python3.9/site-packages/pandas/core/indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
#
# ...

# %% [markdown]
# ### row, column 동시에 선택하기
# - `loc`, `iloc` 속성을 이용할 때, 콤마를 이용하여 둘 다 명시 가능

# %%
train_data.loc[[986, 100, 110, 990], ['Survived', 'Name', 'Sex', 'Age']]
# Out:
#      Survived                             Name     Sex   Age
# 986         0            Montvila, Rev. Juozas    male  27.0
# 100         0          Braund, Mr. Owen Harris    male  22.0
# 110         1  Sandstrom, Miss. Marguerite Rut  female   4.0
# 990         0              Dooley, Mr. Patrick    male  32.0

# %%
train_data.iloc[[0, 100, 200 ,2], [1, 4, 5]]
# Out:
#      Survived     Sex   Age
# 100         0    male  22.0
# 200         0  female  28.0
# 300         0    male  28.0
# 102         1  female  26.0

# %% [markdown]
# ## DataFrame Boolean Selection으로 데이터 선택하기

# %%
train_data = pd.read_csv(os.path.join(data_path, file_name))
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### boolean selection으로 row 선택하기
# - numpy에서와 동일한 방식으로 해당 조건에 맞는 row만 선택

# %% [markdown]
# #### 실습\) 30대이면서 1등석에 탄 사람 선택하기

# %%
pass_class = train_data['Pclass'] == 1
pass_age = (train_data['Age'] >= 30 ) & (train_data['Age'] <40)
train_data[pass_class & pass_age]
# Out:
#      PassengerId  Survived  Pclass  \
# 101            2         1       1
# 103            4         1       1
# 161           62         1       1
# 237          138         0       1
# 315          216         1       1
# 318          219         1       1
# 324          225         1       1
# 330          231         1       1
# 348          249         1       1
# 357          258         1       1
# 358          259         1       1
# 369          270         1       1
# 373          274         0       1
# 409          310         1       1
# 418          319         1       1
# 425          326         1       1
# 432          333         0       1
# 483          384         1       1
# 490          391         1       1
# 512          413         1       1
# 547          448         1       1
# 552          453         0       1
# 586          487         1       1
# 612          513         1       1
# 620          521         1       1
# ...

# %% [markdown]
# ## DataFrame에 column 추가 & 삭제하기
#
# ### 새 column 추가하기
# - [] 사용하여 추가하기
# - insert 함수 사용하여 원하는 위치에 추가하기

# %%
train_data.head()
# Out:
#      PassengerId  Survived  Pclass  \
# 100            1         0       3
# 101            2         1       1
# 102            3         1       3
# 103            4         1       1
# 104            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 100                            Braund, Mr. Owen Harris    male  22.0      1
# 101  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 102                             Heikkinen, Miss. Laina  female  26.0      0
# 103       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 104                           Allen, Mr. William Henry    male  35.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 100      0         A/5 21171   7.2500   NaN        S
# 101      0          PC 17599  71.2833   C85        C
# 102      0  STON/O2. 3101282   7.9250   NaN        S
# 103      0            113803  53.1000  C123        S
# ...

# %%
train_data['Age_Double'] = train_data['Age'] * 2 # 마지막에 column 추가
train_data.head()
# Out:
#      PassengerId  Survived  Pclass  \
# 100            1         0       3
# 101            2         1       1
# 102            3         1       3
# 103            4         1       1
# 104            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 100                            Braund, Mr. Owen Harris    male  22.0      1
# 101  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 102                             Heikkinen, Miss. Laina  female  26.0      0
# 103       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 104                           Allen, Mr. William Henry    male  35.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  Age_Double
# 100      0         A/5 21171   7.2500   NaN        S        44.0
# 101      0          PC 17599  71.2833   C85        C        76.0
# 102      0  STON/O2. 3101282   7.9250   NaN        S        52.0
# ...

# %%
train_data['Age_Tripple'] = train_data['Age'] + train_data['Age_Double'] # 기존 column들을 더해서 새로운 column 생성
train_data.head()
# Out:
#      PassengerId  Survived  Pclass  \
# 100            1         0       3
# 101            2         1       1
# 102            3         1       3
# 103            4         1       1
# 104            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 100                            Braund, Mr. Owen Harris    male  22.0      1
# 101  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 102                             Heikkinen, Miss. Laina  female  26.0      0
# 103       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 104                           Allen, Mr. William Henry    male  35.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  Age_Double  Age_Tripple
# 100      0         A/5 21171   7.2500   NaN        S        44.0         66.0
# 101      0          PC 17599  71.2833   C85        C        76.0        114.0
# ...

# %%
train_data.insert(3, 'Fare10', train_data['Fare'] / 10) # insert 함수를 사용하여 원하는 location에 column 삽입
train_data.head()
# Out:
#      PassengerId  Survived  Pclass   Fare10  \
# 100            1         0       3  0.72500
# 101            2         1       1  7.12833
# 102            3         1       3  0.79250
# 103            4         1       1  5.31000
# 104            5         0       3  0.80500
#
#                                                   Name     Sex   Age  SibSp  \
# 100                            Braund, Mr. Owen Harris    male  22.0      1
# 101  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 102                             Heikkinen, Miss. Laina  female  26.0      0
# 103       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 104                           Allen, Mr. William Henry    male  35.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  Age_Double  Age_Tripple
# 100      0         A/5 21171   7.2500   NaN        S        44.0         66.0
# 101      0          PC 17599  71.2833   C85        C        76.0        114.0
# ...

# %% [markdown]
# ### column 삭제하기
# - drop 함수 사용하여 삭제
#     - 기본 옵션 `inplace = False`: 해당 컬럼 삭제한 복사본 반환
#     - `inplace = True`: 원본에 해당 컬럼 삭제
# - 리스트를 사용하여 멀티플 column 삭제 가능

# %%
train_data.drop('Age_Tripple', axis = 1) # inplace = False 기 때문에 복사본 리턴
# Out:
#      PassengerId  Survived  Pclass   Fare10  \
# 100            1         0       3  0.72500
# 101            2         1       1  7.12833
# 102            3         1       3  0.79250
# 103            4         1       1  5.31000
# 104            5         0       3  0.80500
# ..           ...       ...     ...      ...
# 986          887         0       2  1.30000
# 987          888         1       1  3.00000
# 988          889         0       3  2.34500
# 989          890         1       1  3.00000
# 990          891         0       3  0.77500
#
#                                                   Name     Sex   Age  SibSp  \
# 100                            Braund, Mr. Owen Harris    male  22.0      1
# 101  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 102                             Heikkinen, Miss. Laina  female  26.0      0
# 103       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
train_data.drop('Age_Tripple', axis = 1, inplace = True)
train_data.head()
# Out:
#      PassengerId  Survived  Pclass   Fare10  \
# 100            1         0       3  0.72500
# 101            2         1       1  7.12833
# 102            3         1       3  0.79250
# 103            4         1       1  5.31000
# 104            5         0       3  0.80500
#
#                                                   Name     Sex   Age  SibSp  \
# 100                            Braund, Mr. Owen Harris    male  22.0      1
# 101  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 102                             Heikkinen, Miss. Laina  female  26.0      0
# 103       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 104                           Allen, Mr. William Henry    male  35.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  Age_Double
# 100      0         A/5 21171   7.2500   NaN        S        44.0
# 101      0          PC 17599  71.2833   C85        C        76.0
# ...

# %%
train_data.drop(['Age_Double', 'Fare10'], axis = 1, inplace = True)
train_data.head()
# Out:
#      PassengerId  Survived  Pclass  \
# 100            1         0       3
# 101            2         1       1
# 102            3         1       3
# 103            4         1       1
# 104            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 100                            Braund, Mr. Owen Harris    male  22.0      1
# 101  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 102                             Heikkinen, Miss. Laina  female  26.0      0
# 103       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 104                           Allen, Mr. William Henry    male  35.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 100      0         A/5 21171   7.2500   NaN        S
# 101      0          PC 17599  71.2833   C85        C
# 102      0  STON/O2. 3101282   7.9250   NaN        S
# 103      0            113803  53.1000  C123        S
# ...

# %% [markdown]
# ## DataFrame column간 상관관계 계산하기
#
# ### 변수(column) 사이의 상관계수(correlation)
# - `corr` 함수를 통해 상관계수 연산 (-1, 1 사이의 결과)
#     - 연속형(숫자형) 데이터에 대해서만 연산
#     - 상관관계는 인과관계를 의미하지 않음

# %%
train_data = pd.read_csv(os.path.join(data_path, file_name))
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_data.corr('pearson', numeric_only=True)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %% [markdown]
# ## DataFrame NaN 데이터 처리

# %%
train_data = pd.read_csv(os.path.join(data_path, file_name))
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### NaN 값 확인
# - `info` 함수를 통하여 개수 확인
# - `isna` 함수를 통해 boolean 타입으로 확인

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train_data.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
train_data['Age'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %% [markdown]
# ### NaN 처리 방법
# - 데이터에서 삭제
#     - `dropna` 함수
#         - 옵션 명시 없을 시 (NaN이 하나라도 존재하는 row는 모두 drop) -> 데이터 손실의 위험
#         - `subset` 파라미터 -> 해당 column의 값이 NaN이면 drop
# - 다른 값으로 치환
#     - `fillna` 함수
# - NaN 데이터 삭제하기

# %%
train_data.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_data.dropna(subset=['Age', 'Cabin'])
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_data.dropna(axis = 1) # axis = 1 -> NaN이 하나라도 있는 column drop
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %% [markdown]
# #### NaN 값 대체하기
# - 평균으로 대체하기
# - 선형보간법 등

# %%
train_data['Age'].fillna(train_data['Age'].mean()) # -> 복사본 반환
#train_data['Age'].fillna(train_data['Age'].mean(), inplace=True) # -> 원본 값 변경
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
# 생존자 나이 평균
mean1 = train_data[train_data['Survived'] == 1]['Age'].mean()

# 사망자 나이 평균
mean0 = train_data[train_data['Survived'] == 0]['Age'].mean() 

print(mean1, mean0)
# Out:
# 28.343689655172415 30.62617924528302

# %%
train_data.loc[train_data['Survived'] == 1, 'Age'] = train_data[train_data['Survived'] == 1]['Age'].fillna(mean1)
train_data.loc[train_data['Survived'] == 0, 'Age'] = train_data[train_data['Survived'] == 0]['Age'].fillna(mean0)

# %%
train_data[train_data['Survived'] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## 숫자 데이터와 범주형 데이터의 이해

# %%
train_data = pd.read_csv(os.path.join(data_path, file_name))
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### info 함수로 각 변수의 데이터 타입 확인
# - 타입 변경은 `astype` 함수를 사용

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### 숫자형(Numerical Type) 데이터
# - 연속성을 띄는 숫자로 이루어진 데이터(크고 작음이 의미가 있음)
#     - 예시: Age, Fare 등

# %% [markdown]
# ### 범주형(Categorical Type) 데이터
# - 연속적이지 않은 값(대부분의 경우 숫자를 제외한 나머지 값)을 갖는 데이터를 의미
#     - 예시: Name, Sex, Ticket, Cabin, Embarked 등
# - 또한, 숫자형 타입이라 할 지라도 개념적으로 범주형으로 처리해야 할 경우가 있음
#     - 예시: Pclass

# %% [markdown]
# ## 숫자 데이터의 범주형 데이터화

# %% [markdown]
# #### Pclass 변수 변환하기
# - `astype` 사용하여 간단히 타입만 변환

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train_data['Pclass'] = train_data['Pclass'].astype('str')

# %% [markdown]
# #### Age 변수 변환하기
# - 변환 로직을 함수로 만든 후, apply 함수로 적용
# - numpy와 pandas에서는 for문 사용을 최소화 해야함

# %%
import math

# %%
def age_categorize(age):
    if math.isnan(age):
        return -1
    return math.floor(age / 10) * 10

# %%
train_data['Age'].apply(age_categorize)
# Out:
# 0      20
# 1      30
# 2      20
# 3      30
# 4      30
#        ..
# 886    20
# 887    10
# 888    -1
# 889    20
# 890    30
# Name: Age, Length: 891, dtype: int64

# %% [markdown]
# ## 범주형 데이터 전처리 하기(one-hot encoding)
#
# ### One-Hot Encoding
# - 범주형 데이터는 분석단게에서 계산이 어렵기 때문에 숫자형으로 변경이 필요함
# - 범주형 데이터의 각 범주(category)를 column 레벨로 변경
# - 해당 범주에 해당하면 1, 아니면 0으로 채우는 인코딩 기법
# - `pandas.get_dummies()` 함수 사용
#     - `drop_first`: 첫 번째 카테고리 값은 사용하지 않음

# %%
pd.get_dummies(train_data, columns=['Pclass', 'Sex', 'Embarked'], drop_first=False)
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 888          889         0           Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
# ...

# %%
pd.get_dummies(train_data, columns=['Pclass', 'Sex', 'Embarked'], drop_first=True)
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 888          889         0           Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# # DataFrame의 그룹핑

# %% [markdown]
# ## DataFrame group by 이해하기

# %%
df = pd.read_csv(os.path.join(data_path, file_name))
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### GroupBy gruops 속성
# - 각 그룹과 그룹에 속한 index를 dict 형태로 표현

# %%
class_group = df.groupby('Pclass')
class_group

# %%
class_group.groups
# Out:
# {1: [1, 3, 6, 11, 23, 27, 30, 31, 34, 35, 52, 54, 55, 61, 62, 64, 83, 88, 92, 96, 97, 102, 110, 118, 124, 136, 137, 139, 151, 155, 166, 168, 170, 174, 177, 185, 187, 194, 195, 209, 215, 218, 224, 230, 245, 248, 252, 256, 257, 258, 262, 263, 268, 269, 270, 273, 275, 284, 290, 291, 295, 297, 298, 299, 305, 306, 307, 309, 310, 311, 318, 319, 325, 329, 331, 332, 334, 336, 337, 339, 341, 351, 356, 366, 369, 370, 373, 375, 377, 380, 383, 390, 393, 412, 430, 434, 435, 438, 445, 447, ...], 2: [9, 15, 17, 20, 21, 33, 41, 43, 53, 56, 58, 66, 70, 72, 78, 84, 98, 99, 117, 120, 122, 123, 133, 134, 135, 144, 145, 148, 149, 150, 161, 178, 181, 183, 190, 191, 193, 199, 211, 213, 217, 219, 221, 226, 228, 232, 234, 236, 237, 238, 239, 242, 247, 249, 259, 265, 272, 277, 288, 292, 303, 308, 312, 314, 316, 317, 322, 323, 327, 340, 342, 343, 344, 345, 346, 357, 361, 385, 387, 389, 397, 398, 399, 405, 407, 413, 416, 417, 418, 426, 427, 432, 437, 439, 440, 443, 446, 450, 458, 463, ...], 3: [0, 2, 4, 5, 7, 8
# ...

# %%
gender_group = df.groupby('Sex')
gender_group.groups
# Out:
# {'female': [1, 2, 3, 8, 9, 10, 11, 14, 15, 18, 19, 22, 24, 25, 28, 31, 32, 38, 39, 40, 41, 43, 44, 47, 49, 52, 53, 56, 58, 61, 66, 68, 71, 79, 82, 84, 85, 88, 98, 100, 106, 109, 111, 113, 114, 119, 123, 128, 132, 133, 136, 140, 141, 142, 147, 151, 156, 161, 166, 167, 172, 177, 180, 184, 186, 190, 192, 194, 195, 198, 199, 205, 208, 211, 215, 216, 218, 229, 230, 233, 235, 237, 240, 241, 246, 247, 251, 254, 255, 256, 257, 258, 259, 264, 268, 269, 272, 274, 275, 276, ...], 'male': [0, 4, 5, 6, 7, 12, 13, 16, 17, 20, 21, 23, 26, 27, 29, 30, 33, 34, 35, 36, 37, 42, 45, 46, 48, 50, 51, 54, 55, 57, 59, 60, 62, 63, 64, 65, 67, 69, 70, 72, 73, 74, 75, 76, 77, 78, 80, 81, 83, 86, 87, 89, 90, 91, 92, 93, 94, 95, 96, 97, 99, 101, 102, 103, 104, 105, 107, 108, 110, 112, 115, 116, 117, 118, 120, 121, 122, 124, 125, 126, 127, 129, 130, 131, 134, 135, 137, 138, 139, 143, 144, 145, 146, 148, 149, 150, 152, 153, 154, 155, ...]}

# %% [markdown]
# #### groupping 함수
# - 그룹 데이터에 적용 가능한 통계 함수(NaN은 제외하여 연산)
# - count - 데이터 개수
# - sum - 데이터의 합
# - mean, std, var - 평균, 표준편차, 분산
# - min, max - 최소, 최대

# %%
class_group.count()

# Age, Cabin 등은 NaN 때문에 빠지는 값들이 있다
# Out:
#         PassengerId  Survived  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass
# 1               216       216   216  216  186    216    216     216   216
# 2               184       184   184  184  173    184    184     184   184
# 3               491       491   491  491  355    491    491     491   491
#
#         Cabin  Embarked
# Pclass
# 1         176       214
# 2          16       184
# 3          12       491

# %%
class_group.sum()
# Out:
#         PassengerId  Survived  \
# Pclass
# 1             99705       136
# 2             82056        87
# 3            215625       119
#
#                                                      Name  \
# Pclass
# 1       Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       Nasser, Mrs. Nicholas (Adele Achem)Hewlett, Mr...
# 3       Braund, Mr. Owen HarrisHeikkinen, Miss. LainaA...
#
#                                                       Sex      Age  SibSp  \
# Pclass
# 1       femalefemalemalefemalemalemalemalefemalemalema...  7111.42     90
# 2       femalefemalemalemalemalemalefemalefemalefemale...  5168.83     74
# 3       malefemalemalemalemalefemalefemalemalemalefema...  8924.92    302
#
#         Parch                                             Ticket        Fare  \
# Pclass
# 1          77  PC 175991138031746311378311378819950PC 17601PC...  18177.4125
# 2          70  237736248706244373239865248698C.A. 2457911668S...   3801.8417
# ...

# %%
class_group.mean(numeric_only=True)['Survived']
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
class_group.max(numeric_only=True)
# Out:
#         PassengerId  Survived   Age  SibSp  Parch      Fare
# Pclass
# 1               890         1  80.0      3      4  512.3292
# 2               887         1  70.0      3      3   73.5000
# 3               891         1  74.0      8      6   69.5500

# %%
df.groupby('Sex').mean(numeric_only=True)['Survived']
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %% [markdown]
# #### 복수 columns로 groupping 하기
# - groupby에 column 리스트를 전달
# - 통계함수를 적용한 결과는 multi index를 가지는 dataframe
# ---
# - 예제\) 클래스와 성별에 따른 생존률 구해보기

# %%
df.groupby(['Pclass', 'Sex']).mean(numeric_only=True)
# Out:
#                PassengerId  Survived        Age     SibSp     Parch  \
# Pclass Sex
# 1      female   469.212766  0.968085  34.611765  0.553191  0.457447
#        male     455.729508  0.368852  41.281386  0.311475  0.278689
# 2      female   443.105263  0.921053  28.722973  0.486842  0.605263
#        male     447.962963  0.157407  30.740707  0.342593  0.222222
# 3      female   399.729167  0.500000  21.750000  0.895833  0.798611
#        male     455.515850  0.135447  26.507589  0.498559  0.224784
#
#                      Fare
# Pclass Sex
# 1      female  106.125798
#        male     67.226127
# 2      female   21.970121
#        male     19.741782
# 3      female   16.118810
#        male     12.661633

# %%
df.groupby(['Pclass', 'Sex']).mean(numeric_only=True).index
# Out:
# MultiIndex([(1, 'female'),
#             (1,   'male'),
#             (2, 'female'),
#             (2,   'male'),
#             (3, 'female'),
#             (3,   'male')],
#            names=['Pclass', 'Sex'])

# %% [markdown]
# #### index를 이용한 group by
# - index가 있는 경우, groupby 함수에 level 사용 가능
#     - level은 index의 depth를 의미하며, 가장 왼쪽부터 0부터 증가
# - `set_index` 함수
#     - column 데이터를 index 레벨로 변경
# - `reset_index` 함수
#     - 인덱스 초기화

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.set_index(['Pclass', 'Sex']).reset_index()
# Out:
#      Pclass     Sex  PassengerId  Survived  \
# 0         3    male            1         0
# 1         1  female            2         1
# 2         3  female            3         1
# 3         1  female            4         1
# 4         3    male            5         0
# ..      ...     ...          ...       ...
# 886       2    male          887         0
# 887       1  female          888         1
# 888       3  female          889         0
# 889       1    male          890         1
# 890       3    male          891         0
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# ...

# %%
df.set_index('Age').groupby(level=0).mean(numeric_only=True)
# Out:
#        PassengerId  Survived  Pclass  SibSp  Parch      Fare
# Age
# 0.42         804.0       1.0     3.0    0.0    1.0    8.5167
# 0.67         756.0       1.0     2.0    1.0    1.0   14.5000
# 0.75         557.5       1.0     3.0    2.0    1.0   19.2583
# 0.83         455.5       1.0     2.0    0.5    1.5   23.8750
# 0.92         306.0       1.0     1.0    1.0    2.0  151.5500
# ...            ...       ...     ...    ...    ...       ...
# 70.00        709.5       0.0     1.5    0.5    0.5   40.7500
# 70.50        117.0       0.0     3.0    0.0    0.0    7.7500
# 71.00        295.5       0.0     1.0    0.0    0.0   42.0792
# 74.00        852.0       0.0     3.0    0.0    0.0    7.7750
# 80.00        631.0       1.0     1.0    0.0    0.0   30.0000
#
# [88 rows x 6 columns]

# %% [markdown]
# #### 나이대별로 생존율 구하기

# %%
import math

def age_categorize(age):
    if math.isnan(age):
        return -1
    return math.floor(age / 10) * 10

# %%
df.set_index('Age').groupby(age_categorize).mean(numeric_only=True)['Survived']
# Out:
# Age
# -1     0.293785
#  0     0.612903
#  10    0.401961
#  20    0.350000
#  30    0.437126
#  40    0.382022
#  50    0.416667
#  60    0.315789
#  70    0.000000
#  80    1.000000
# Name: Survived, dtype: float64

# %% [markdown]
# #### Multi Index를 이용한 groupping

# %%
df.set_index(['Pclass', 'Age']).groupby(level=[0, 1]).mean(numeric_only=True)
# Out:
#               PassengerId  Survived  SibSp  Parch      Fare
# Pclass Age
# 1      0.92         306.0       1.0    1.0    2.0  151.5500
#        2.00         298.0       0.0    1.0    2.0  151.5500
#        4.00         446.0       1.0    0.0    2.0   81.8583
#        11.00        803.0       1.0    1.0    2.0  120.0000
#        14.00        436.0       1.0    1.0    2.0  120.0000
# ...                   ...       ...    ...    ...       ...
# 3      61.00        327.0       0.0    0.0    0.0    6.2375
#        63.00        484.0       1.0    0.0    0.0    9.5875
#        65.00        281.0       0.0    0.0    0.0    7.7500
#        70.50        117.0       0.0    0.0    0.0    7.7500
#        74.00        852.0       0.0    0.0    0.0    7.7750
#
# [182 rows x 5 columns]

# %%
df.set_index(['Pclass', 'Age']).groupby(level=[1, 0]).mean(numeric_only=True)
# Out:
#               PassengerId  Survived  SibSp  Parch      Fare
# Age   Pclass
# 0.42  3             804.0       1.0    0.0    1.0    8.5167
# 0.67  2             756.0       1.0    1.0    1.0   14.5000
# 0.75  3             557.5       1.0    2.0    1.0   19.2583
# 0.83  2             455.5       1.0    0.5    1.5   23.8750
# 0.92  1             306.0       1.0    1.0    2.0  151.5500
# ...                   ...       ...    ...    ...       ...
# 70.00 2             673.0       0.0    0.0    0.0   10.5000
# 70.50 3             117.0       0.0    0.0    0.0    7.7500
# 71.00 1             295.5       0.0    0.0    0.0   42.0792
# 74.00 3             852.0       0.0    0.0    0.0    7.7750
# 80.00 1             631.0       1.0    0.0    0.0   30.0000
#
# [182 rows x 5 columns]

# %% [markdown]
# #### Aggregate함수(집계함수) 사용하기
# - groupby 결과에 집계함수를 적용하여 그룹별 데이터 확인 가능

# %%
df.set_index(['Pclass', 'Age']).groupby(level=[0, 1]).aggregate([np.mean, np.sum, np.max])
# Out:
# /var/folders/ws/yk5_j0490vnb543l1m2l7mtc0000gn/T/ipykernel_34764/1738585118.py:1: FutureWarning: The provided callable <function mean at 0x105705c10> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.set_index(['Pclass', 'Age']).groupby(level=[0, 1]).aggregate([np.mean, np.sum, np.max])
# /var/folders/ws/yk5_j0490vnb543l1m2l7mtc0000gn/T/ipykernel_34764/1738585118.py:1: FutureWarning: The provided callable <function sum at 0x105702790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.set_index(['Pclass', 'Age']).groupby(level=[0, 1]).aggregate([np.mean, np.sum, np.max])
# ...

# %% [markdown]
# ## `transform` 함수의 이해 및 활용하기
#
# ### `transform` 함수
# - groupby 후 transform 함수를 사용하면 원래의 index를 유지한 상태로 통계함수를 적용
# - 전체 데이터의 집계가 아닌 각 그룹에서의 집계를 계산
# - 새로 생성된 데이터를 원본 dataframe과 합치기 쉬움

# %%
df.groupby('Pclass').mean(numeric_only=True)
# Out:
#         PassengerId  Survived        Age     SibSp     Parch       Fare
# Pclass
# 1        461.597222  0.629630  38.233441  0.416667  0.356481  84.154687
# 2        445.956522  0.472826  29.877630  0.402174  0.380435  20.662183
# 3        439.154786  0.242363  25.140620  0.615071  0.393075  13.675550

# %%
df.groupby('Pclass').transform(np.mean,numeric_only=True)
# Out:
# /var/folders/ws/yk5_j0490vnb543l1m2l7mtc0000gn/T/ipykernel_34764/60995919.py:1: FutureWarning: The provided callable <function mean at 0x105705c10> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby('Pclass').transform(np.mean,numeric_only=True)
#      PassengerId  Survived        Age     SibSp     Parch       Fare
# 0     439.154786  0.242363  25.140620  0.615071  0.393075  13.675550
# 1     461.597222  0.629630  38.233441  0.416667  0.356481  84.154687
# 2     439.154786  0.242363  25.140620  0.615071  0.393075  13.675550
# 3     461.597222  0.629630  38.233441  0.416667  0.356481  84.154687
# 4     439.154786  0.242363  25.140620  0.615071  0.393075  13.675550
# ..           ...       ...        ...       ...       ...        ...
# 886   445.956522  0.472826  29.877630  0.402174  0.380435  20.662183
# ...

# %%
df['Age2'] = df.groupby('Pclass').transform(np.mean,numeric_only=True)['Age']
df
# Out:
# /var/folders/ws/yk5_j0490vnb543l1m2l7mtc0000gn/T/ipykernel_34764/4180614136.py:1: FutureWarning: The provided callable <function mean at 0x105705c10> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df['Age2'] = df.groupby('Pclass').transform(np.mean,numeric_only=True)['Age']
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# ...

# %%
df.groupby(['Pclass', 'Sex']).mean(numeric_only=True)
# Out:
#                PassengerId  Survived        Age     SibSp     Parch  \
# Pclass Sex
# 1      female   469.212766  0.968085  34.611765  0.553191  0.457447
#        male     455.729508  0.368852  41.281386  0.311475  0.278689
# 2      female   443.105263  0.921053  28.722973  0.486842  0.605263
#        male     447.962963  0.157407  30.740707  0.342593  0.222222
# 3      female   399.729167  0.500000  21.750000  0.895833  0.798611
#        male     455.515850  0.135447  26.507589  0.498559  0.224784
#
#                      Fare       Age2
# Pclass Sex
# 1      female  106.125798  38.233441
#        male     67.226127  38.233441
# 2      female   21.970121  29.877630
#        male     19.741782  29.877630
# 3      female   16.118810  25.140620
#        male     12.661633  25.140620

# %%
df['Age3'] = df.groupby(['Pclass', 'Sex']).transform(np.mean,numeric_only=True)['Age']
df
# Out:
# /var/folders/ws/yk5_j0490vnb543l1m2l7mtc0000gn/T/ipykernel_34764/4274099223.py:1: FutureWarning: The provided callable <function mean at 0x105705c10> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df['Age3'] = df.groupby(['Pclass', 'Sex']).transform(np.mean,numeric_only=True)['Age']
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# ...

# %% [markdown]
# ## pivot, pivot_table 함수의 이해 및 활용하기

# %%
df = pd.DataFrame({
    '지역': ['서울', '서울', '서울', '경기', '경기', '부산', '서울', '서울', '부산', '경기', '경기', '경기'],
    '요일': ['월요일', '월요일', '수요일', '월요일', '화요일', '월요일', '목요일', '금요일', '화요일', '수요일', '목요일', '금요일'],
    '강수량': [100, 80, 1000, 200, 200, 100, 50, 100, 200, 100, 50, 100],
    '강수확률': [80, 70, 90, 10, 20, 30, 50, 90, 20, 80, 50, 10]
                })

df
# Out:
#     지역   요일   강수량  강수확률
# 0   서울  월요일   100    80
# 1   서울  월요일    80    70
# 2   서울  수요일  1000    90
# 3   경기  월요일   200    10
# 4   경기  화요일   200    20
# 5   부산  월요일   100    30
# 6   서울  목요일    50    50
# 7   서울  금요일   100    90
# 8   부산  화요일   200    20
# 9   경기  수요일   100    80
# 10  경기  목요일    50    50
# 11  경기  금요일   100    10

# %% [markdown]
# ### pivot
# - dataframe의 형태를 변경
# - 인덱스, 컬럼, 데이터로 사용할 컬럼을 명시

# %%
df.pivot(index = '지역', columns='요일')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[188], line 1
# ----> 1 df.pivot(index = '지역', columns='요일')
#
# File ~/miniforge3/envs/dl/lib/python3.9/site-packages/pandas/core/frame.py:9326, in DataFrame.pivot(self, columns, index, values)
#    9319 @Substitution("")
#    9320 @Appender(_shared_docs["pivot"])
#    9321 def pivot(
#    9322     self, *, columns, index=lib.no_default, values=lib.no_default
#    9323 ) -> DataFrame:
#    9324     from pandas.core.reshape.pivot import pivot
# -> 9326     return pivot(self, index=index, columns=columns, values=values)
#
# File ~/miniforge3/envs/dl/lib/python3.9/site-packages/pandas/core/reshape/pivot.py:570, in pivot(data, columns, index, values)
#     566         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# ...

# %% [markdown]
# ### pivot_table
# - 기능적으로 pivot과 동일
# - pivot과 차이점
#     - 중복되는 모호한 값이 있을 경우, aggregation 함수 사용하여 값을 채움

# %%
pd.pivot_table(df, index = '요일', columns = '지역', aggfunc = np.mean)
# Out:
# /var/folders/ws/yk5_j0490vnb543l1m2l7mtc0000gn/T/ipykernel_34764/3976538692.py:1: FutureWarning: The provided callable <function mean at 0x105705c10> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pd.pivot_table(df, index = '요일', columns = '지역', aggfunc = np.mean)
#        강수량                 강수확률
# 지역      경기     부산      서울    경기    부산    서울
# 요일
# 금요일  100.0    NaN   100.0  10.0   NaN  90.0
# 목요일   50.0    NaN    50.0  50.0   NaN  50.0
# 수요일  100.0    NaN  1000.0  80.0   NaN  90.0
# 월요일  200.0  100.0    90.0  10.0  30.0  75.0
# 화요일  200.0  200.0     NaN  20.0  20.0   NaN

# %% [markdown]
# ## stack, unstack 함수의 이해 및 활용

# %%
df = pd.DataFrame({
    '지역': ['서울', '서울', '서울', '경기', '경기', '부산', '서울', '서울', '부산', '경기', '경기', '경기'],
    '요일': ['월요일', '화요일', '수요일', '월요일', '화요일', '월요일', '목요일', '금요일', '화요일', '수요일', '목요일', '금요일'],
    '강수량': [100, 80, 1000, 200, 200, 100, 50, 100, 200, 100, 50, 100],
    '강수확률': [80, 70, 90, 10, 20, 30, 50, 90, 20, 80, 50, 10]
                })

df
# Out:
#     지역   요일   강수량  강수확률
# 0   서울  월요일   100    80
# 1   서울  화요일    80    70
# 2   서울  수요일  1000    90
# 3   경기  월요일   200    10
# 4   경기  화요일   200    20
# 5   부산  월요일   100    30
# 6   서울  목요일    50    50
# 7   서울  금요일   100    90
# 8   부산  화요일   200    20
# 9   경기  수요일   100    80
# 10  경기  목요일    50    50
# 11  경기  금요일   100    10

# %% [markdown]
# ### stack \& unstack
# - stack: 컬럼 레벨에서 인덱스 레벨로 dataframe 변경
#     - 즉, 데이터를 쌓아 올리는 개념으로 이해하면 쉬움
# - unstack: 인덱스 레벨에서 컬럼 레벨로 dataframe 변경
#     - stack의 반대 operation
# - 두 함수는 역의 관계에 있음

# %%
new_df = df.set_index(['지역','요일'])
new_df
# Out:
#          강수량  강수확률
# 지역 요일
# 서울 월요일   100    80
#    화요일    80    70
#    수요일  1000    90
# 경기 월요일   200    10
#    화요일   200    20
# 부산 월요일   100    30
# 서울 목요일    50    50
#    금요일   100    90
# 부산 화요일   200    20
# 경기 수요일   100    80
#    목요일    50    50
#    금요일   100    10

# %%
new_df.index
# Out:
# MultiIndex([('서울', '월요일'),
#             ('서울', '화요일'),
#             ('서울', '수요일'),
#             ('경기', '월요일'),
#             ('경기', '화요일'),
#             ('부산', '월요일'),
#             ('서울', '목요일'),
#             ('서울', '금요일'),
#             ('부산', '화요일'),
#             ('경기', '수요일'),
#             ('경기', '목요일'),
#             ('경기', '금요일')],
#            names=['지역', '요일'])

# %%
new_df.unstack(0)
# Out:
#        강수량                 강수확률
# 지역      경기     부산      서울    경기    부산    서울
# 요일
# 금요일  100.0    NaN   100.0  10.0   NaN  90.0
# 목요일   50.0    NaN    50.0  50.0   NaN  50.0
# 수요일  100.0    NaN  1000.0  80.0   NaN  90.0
# 월요일  200.0  100.0   100.0  10.0  30.0  80.0
# 화요일  200.0  200.0    80.0  20.0  20.0  70.0

# %%
new_df.unstack(1)
# Out:
#       강수량                              강수확률
# 요일    금요일   목요일     수요일    월요일    화요일   금요일   목요일   수요일   월요일   화요일
# 지역
# 경기  100.0  50.0   100.0  200.0  200.0  10.0  50.0  80.0  10.0  20.0
# 부산    NaN   NaN     NaN  100.0  200.0   NaN   NaN   NaN  30.0  20.0
# 서울  100.0  50.0  1000.0  100.0   80.0  90.0  50.0  90.0  80.0  70.0

# %%
new_df.unstack(0).stack(0)
# Out:
# /var/folders/ws/yk5_j0490vnb543l1m2l7mtc0000gn/T/ipykernel_34764/3150064354.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   new_df.unstack(0).stack(0)
# 지역           경기     부산      서울
# 요일
# 금요일 강수량   100.0    NaN   100.0
#     강수확률   10.0    NaN    90.0
# 목요일 강수량    50.0    NaN    50.0
#     강수확률   50.0    NaN    50.0
# 수요일 강수량   100.0    NaN  1000.0
#     강수확률   80.0    NaN    90.0
# 월요일 강수량   200.0  100.0   100.0
#     강수확률   10.0   30.0    80.0
# 화요일 강수량   200.0  200.0    80.0
#     강수확률   20.0   20.0    70.0

# %%
new_df.unstack(0).stack(1)
# Out:
# /var/folders/ws/yk5_j0490vnb543l1m2l7mtc0000gn/T/ipykernel_34764/1778177021.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   new_df.unstack(0).stack(1)
#            강수량  강수확률
# 요일  지역
# 금요일 경기   100.0  10.0
#     서울   100.0  90.0
# 목요일 경기    50.0  50.0
#     서울    50.0  50.0
# 수요일 경기   100.0  80.0
#     서울  1000.0  90.0
# 월요일 경기   200.0  10.0
#     부산   100.0  30.0
#     서울   100.0  80.0
# 화요일 경기   200.0  20.0
#     부산   200.0  20.0
#     서울    80.0  70.0

# %% [markdown]
# # DataFrame의 병합과 조인

# %% [markdown]
# ## Concat 함수로 데이터프레임 병합하기

# %%
# import pandas as pd
# import numpy as np

# %% [markdown]
# ### concat 함수 사용하여 dataframe 병합하기
# - `pandas.concat()` 함수
# - 축을 따라 dataframe을 병합 가능
#     - 기본 axis = 0 -> 행단위 병합
#     - axis = 1 -> column 단위 병합

# %%
df1 = pd.DataFrame({'key1': np.arange(10), 'value1': np.random.randn(10)})
df2 = pd.DataFrame({'key1': np.arange(10), 'value1': np.random.randn(10)})

# %%
df1
# Out:
#    key1    value1
# 0     0 -0.048576
# 1     1 -0.918382
# 2     2 -0.830199
# 3     3  0.946116
# 4     4 -0.214934
# 5     5  0.738432
# 6     6 -0.461261
# 7     7 -0.293269
# 8     8  0.296926
# 9     9 -1.403926

# %%
df2
# Out:
#    key1    value1
# 0     0 -0.708746
# 1     1  0.379656
# 2     2  0.141278
# 3     3 -0.976487
# 4     4 -0.089943
# 5     5  0.382526
# 6     6 -1.644595
# 7     7 -0.611875
# 8     8 -0.458564
# 9     9 -1.181675

# %%
pd.concat([df1,df2]) # 병합을 해도 인덱스가 유지
# Out:
#    key1    value1
# 0     0 -0.048576
# 1     1 -0.918382
# 2     2 -0.830199
# 3     3  0.946116
# 4     4 -0.214934
# 5     5  0.738432
# 6     6 -0.461261
# 7     7 -0.293269
# 8     8  0.296926
# 9     9 -1.403926
# 0     0 -0.708746
# 1     1  0.379656
# 2     2  0.141278
# 3     3 -0.976487
# 4     4 -0.089943
# 5     5  0.382526
# 6     6 -1.644595
# 7     7 -0.611875
# 8     8 -0.458564
# 9     9 -1.181675

# %%
pd.concat([df1,df2], ignore_index=True) # 기존 인덱스 무시하고 새롭게 할당
# Out:
#     key1    value1
# 0      0 -0.048576
# 1      1 -0.918382
# 2      2 -0.830199
# 3      3  0.946116
# 4      4 -0.214934
# 5      5  0.738432
# 6      6 -0.461261
# 7      7 -0.293269
# 8      8  0.296926
# 9      9 -1.403926
# 10     0 -0.708746
# 11     1  0.379656
# 12     2  0.141278
# 13     3 -0.976487
# 14     4 -0.089943
# 15     5  0.382526
# 16     6 -1.644595
# 17     7 -0.611875
# 18     8 -0.458564
# 19     9 -1.181675

# %%
pd.concat([df1,df2], axis=1) # 열레벨로 concat -> 굉장히 드물게 사용
# Out:
#    key1    value1  key1    value1
# 0     0 -0.048576     0 -0.708746
# 1     1 -0.918382     1  0.379656
# 2     2 -0.830199     2  0.141278
# 3     3  0.946116     3 -0.976487
# 4     4 -0.214934     4 -0.089943
# 5     5  0.738432     5  0.382526
# 6     6 -0.461261     6 -1.644595
# 7     7 -0.293269     7 -0.611875
# 8     8  0.296926     8 -0.458564
# 9     9 -1.403926     9 -1.181675

# %% [markdown]
# - column 명이 다른 경우

# %%
df3 = pd.DataFrame({'key2': np.arange(10), 'value2': np.random.randn(10)})
df3
# Out:
#    key2    value2
# 0     0 -0.317208
# 1     1 -0.725465
# 2     2  0.294828
# 3     3  0.330196
# 4     4 -0.977983
# 5     5 -0.196398
# 6     6  1.716274
# 7     7 -0.325923
# 8     8  1.594132
# 9     9 -0.521468

# %%
pd.concat([df1, df3])
# Out:
#    key1    value1  key2    value2
# 0   0.0 -0.048576   NaN       NaN
# 1   1.0 -0.918382   NaN       NaN
# 2   2.0 -0.830199   NaN       NaN
# 3   3.0  0.946116   NaN       NaN
# 4   4.0 -0.214934   NaN       NaN
# 5   5.0  0.738432   NaN       NaN
# 6   6.0 -0.461261   NaN       NaN
# 7   7.0 -0.293269   NaN       NaN
# 8   8.0  0.296926   NaN       NaN
# 9   9.0 -1.403926   NaN       NaN
# 0   NaN       NaN   0.0 -0.317208
# 1   NaN       NaN   1.0 -0.725465
# 2   NaN       NaN   2.0  0.294828
# 3   NaN       NaN   3.0  0.330196
# 4   NaN       NaN   4.0 -0.977983
# 5   NaN       NaN   5.0 -0.196398
# 6   NaN       NaN   6.0  1.716274
# 7   NaN       NaN   7.0 -0.325923
# 8   NaN       NaN   8.0  1.594132
# 9   NaN       NaN   9.0 -0.521468

# %%
pd.concat([df1, df3], axis = 1)
# Out:
#    key1    value1  key2    value2
# 0     0 -0.048576     0 -0.317208
# 1     1 -0.918382     1 -0.725465
# 2     2 -0.830199     2  0.294828
# 3     3  0.946116     3  0.330196
# 4     4 -0.214934     4 -0.977983
# 5     5  0.738432     5 -0.196398
# 6     6 -0.461261     6  1.716274
# 7     7 -0.293269     7 -0.325923
# 8     8  0.296926     8  1.594132
# 9     9 -1.403926     9 -0.521468

# %% [markdown]
# ## Merge, _join 함수로 데이터프레임 병합하기

# %% [markdown]
# ### dataframe `merge`
# - SQL의 join 처럼 특정한 column을 기준으로 병합
#     - join 방식: `how` 파라미터를 통해 명시
#         - `inner`: 파라미터의 기본값, 일치하는 값이 있는 경우
#         - `left`: left outer join
#         - `right`: right outer join
#         - `outer`: full outer join
#     - `pandas.merge` 함수가 사용됨

# %%
customer = pd.DataFrame({'customer_id' : np.arange(6), 
                    'name' : ['철수'"", '영희', '길동', '영수', '수민', '동건'], 
                    '나이' : [40, 20, 21, 30, 31, 18]})

customer
# Out:
#    customer_id name  나이
# 0            0   철수  40
# 1            1   영희  20
# 2            2   길동  21
# 3            3   영수  30
# 4            4   수민  31
# 5            5   동건  18

# %%
orders = pd.DataFrame({'customer_id' : [1, 1, 2, 2, 2, 3, 3, 1, 4, 9], 
                    'item' : ['치약', '칫솔', '이어폰', '헤드셋', '수건', '생수', '수건', '치약', '생수', '케이스'], 
                    'quantity' : [1, 2, 1, 1, 3, 2, 2, 3, 2, 1]})
orders.head()
# Out:
#    customer_id item  quantity
# 0            1   치약         1
# 1            1   칫솔         2
# 2            2  이어폰         1
# 3            2  헤드셋         1
# 4            2   수건         3

# %%
pd.merge(customer, orders, on = 'customer_id', how='inner')
# Out:
#    customer_id name  나이 item  quantity
# 0            1   영희  20   치약         1
# 1            1   영희  20   칫솔         2
# 2            1   영희  20   치약         3
# 3            2   길동  21  이어폰         1
# 4            2   길동  21  헤드셋         1
# 5            2   길동  21   수건         3
# 6            3   영수  30   생수         2
# 7            3   영수  30   수건         2
# 8            4   수민  31   생수         2

# %%
pd.merge(customer, orders, on = 'customer_id', how='left')
# Out:
#     customer_id name  나이 item  quantity
# 0             0   철수  40  NaN       NaN
# 1             1   영희  20   치약       1.0
# 2             1   영희  20   칫솔       2.0
# 3             1   영희  20   치약       3.0
# 4             2   길동  21  이어폰       1.0
# 5             2   길동  21  헤드셋       1.0
# 6             2   길동  21   수건       3.0
# 7             3   영수  30   생수       2.0
# 8             3   영수  30   수건       2.0
# 9             4   수민  31   생수       2.0
# 10            5   동건  18  NaN       NaN

# %%
pd.merge(customer, orders, on = 'customer_id', how='right')
# Out:
#    customer_id name    나이 item  quantity
# 0            1   영희  20.0   치약         1
# 1            1   영희  20.0   칫솔         2
# 2            2   길동  21.0  이어폰         1
# 3            2   길동  21.0  헤드셋         1
# 4            2   길동  21.0   수건         3
# 5            3   영수  30.0   생수         2
# 6            3   영수  30.0   수건         2
# 7            1   영희  20.0   치약         3
# 8            4   수민  31.0   생수         2
# 9            9  NaN   NaN  케이스         1

# %%
pd.merge(customer, orders, on = 'customer_id', how='outer')
# Out:
#     customer_id name    나이 item  quantity
# 0             0   철수  40.0  NaN       NaN
# 1             1   영희  20.0   치약       1.0
# 2             1   영희  20.0   칫솔       2.0
# 3             1   영희  20.0   치약       3.0
# 4             2   길동  21.0  이어폰       1.0
# 5             2   길동  21.0  헤드셋       1.0
# 6             2   길동  21.0   수건       3.0
# 7             3   영수  30.0   생수       2.0
# 8             3   영수  30.0   수건       2.0
# 9             4   수민  31.0   생수       2.0
# 10            5   동건  18.0  NaN       NaN
# 11            9  NaN   NaN  케이스       1.0

# %% [markdown]
# - index 기준으로 join 하기

# %%
cust1 = customer.set_index('customer_id')
order1 = orders.set_index('customer_id')

# %%
cust1
# Out:
#             name  나이
# customer_id
# 0             철수  40
# 1             영희  20
# 2             길동  21
# 3             영수  30
# 4             수민  31
# 5             동건  18

# %%
order1
# Out:
#             item  quantity
# customer_id
# 1             치약         1
# 1             칫솔         2
# 2            이어폰         1
# 2            헤드셋         1
# 2             수건         3
# 3             생수         2
# 3             수건         2
# 1             치약         3
# 4             생수         2
# 9            케이스         1

# %%
pd.merge(cust1, order1, left_index=True, right_index=True)
# Out:
#             name  나이 item  quantity
# customer_id
# 1             영희  20   치약         1
# 1             영희  20   칫솔         2
# 1             영희  20   치약         3
# 2             길동  21  이어폰         1
# 2             길동  21  헤드셋         1
# 2             길동  21   수건         3
# 3             영수  30   생수         2
# 3             영수  30   수건         2
# 4             수민  31   생수         2

# %% [markdown]
# ### 연습문제
# 1. 가장 많이 팔린 아이템은?
# 2. 영희가 가장 많이 구매한 아이템은?

# %%
pd.merge(customer, orders, on = 'customer_id').groupby('item').sum().sort_values(by='quantity', ascending=False)
# Out:
#       customer_id  name  나이  quantity
# item
# 수건              5  길동영수  51         5
# 생수              7  영수수민  61         4
# 치약              2  영희영희  40         4
# 칫솔              1    영희  20         2
# 이어폰             2    길동  21         1
# 헤드셋             2    길동  21         1

# %%
pd.merge(customer, orders, on = 'customer_id').groupby(['name', 'item']).sum().loc['영희', 'quantity']
# Out:
# item
# 치약    4
# 칫솔    2
# Name: quantity, dtype: int64

# %% [markdown]
# ### join 함수
# - 내부적으로 `pandas.merge` 함수 사용
# - 기본적으로 index를 사용하여 left join

# %%
cust1.join(order1)
# Out:
#             name  나이 item  quantity
# customer_id
# 0             철수  40  NaN       NaN
# 1             영희  20   치약       1.0
# 1             영희  20   칫솔       2.0
# 1             영희  20   치약       3.0
# 2             길동  21  이어폰       1.0
# 2             길동  21  헤드셋       1.0
# 2             길동  21   수건       3.0
# 3             영수  30   생수       2.0
# 3             영수  30   수건       2.0
# 4             수민  31   생수       2.0
# 5             동건  18  NaN       NaN

# %%
cust1.join(order1, how = 'inner')
# Out:
#             name  나이 item  quantity
# customer_id
# 1             영희  20   치약         1
# 1             영희  20   칫솔         2
# 1             영희  20   치약         3
# 2             길동  21  이어폰         1
# 2             길동  21  헤드셋         1
# 2             길동  21   수건         3
# 3             영수  30   생수         2
# 3             영수  30   수건         2
# 4             수민  31   생수         2
